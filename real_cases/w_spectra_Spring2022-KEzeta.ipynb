# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib as mlab
import matplotlib.pyplot as plt
import xarray as xr
import os as os
import matplotlib.gridspec as gridspec
import glob
import netCDF4 as ncdf
from pynhhd import nHHD

import time

from datetime import datetime

# Local import 

from spectra.py_spectra import *

# %%
#-----------------------------------------------------------------
#
# This code can run and plot power spectra from a single day
#

def compute_nhhd(in_dir, out_dir, day, suffix_name = ["HRRR_ECONUS", "RRFS_ECONUS"], analysis_levels = [4, 34]):
    
    def write_npz(filename_src, ur,vr,wr, ud,vd,wd, uh,vh,wh, z, lats, lons):
        
        dct = {'ur': ur, 'vr': vr, 'wr':wr, 
               'ud': ur, 'vd': vr, 'wd':wr,
               'uh': ur, 'vh': vr, 'wh':wr,
               'z':   z, 'lats': lats, 'lons': lons}
        
        filename = filename_src[:-3]+"_nhhd"
        
        np.savez(filename, **dct)
        
        print("Wrote out: ", filename+".npz")
        
    def write_xr(filename_src, ur,vr,wr, ud,vd,wd, uh,vh,wh, fhour, z, lats, lons):

        ds = xr.Dataset({
                        'ur': xr.DataArray(
            data   = ur, dims = ['fhour', 'nz','ny','nx'], 
            coords={"lats": (["ny","nx"], lats), "lons": (["ny","nx"], lons),"z": (["nz"], z), "fhour": (["fhour"], fhour)} ),
                         'vr': xr.DataArray(
            data   = vr, dims = ['fhour', 'nz','ny','nx'],
            coords={"lats": (["ny","nx"], lats), "lons": (["ny","nx"], lons),"z": (["nz"], z), "fhour": (["fhour"], fhour) } ),
                         'wr': xr.DataArray(
            data   = wr, dims = ['fhour', 'nz','ny','nx'], 
            coords={"lats": (["ny","nx"], lats), "lons": (["ny","nx"], lons),"z": (["nz"], z), "fhour": (["fhour"], fhour) } ), 
                         'ud': xr.DataArray(
            data   = ud, dims = ['fhour', 'nz','ny','nx'],
            coords={"lats": (["ny","nx"], lats), "lons": (["ny","nx"], lons),"z": (["nz"], z), "fhour": (["fhour"], fhour) } ),
                         'vd': xr.DataArray(
            data   = vd, dims = ['fhour', 'nz','ny','nx'],
            coords={"lats": (["ny","nx"], lats), "lons": (["ny","nx"], lons),"z": (["nz"], z), "fhour": (["fhour"], fhour) } ),
                         'wd': xr.DataArray(
            data   = wd, dims = ['fhour', 'nz','ny','nx'], 
            coords={"lats": (["ny","nx"], lats), "lons": (["ny","nx"], lons),"z": (["nz"], z), "fhour": (["fhour"], fhour) } ),  
                          'uh': xr.DataArray(
            data   = uh, dims = ['fhour', 'nz','ny','nx'],
            coords={"lats": (["ny","nx"], lats), "lons": (["ny","nx"], lons),"z": (["nz"], z), "fhour": (["fhour"], fhour) } ),
                         'vh': xr.DataArray(
            data   = vh, dims = ['fhour', 'nz','ny','nx'],
            coords={"lats": (["ny","nx"], lats), "lons": (["ny","nx"], lons),"z": (["nz"], z), "fhour": (["fhour"], fhour) } ),
                         'wh': xr.DataArray(
            data   = wh, dims = ['fhour', 'nz','ny','nx'],
            coords={"lats": (["ny","nx"], lats), "lons": (["ny","nx"], lons),"z": (["nz"], z), "fhour": (["fhour"], fhour) } ) })

        filename = filename_src[:-3]+"_nhhd3D.nc"
        
        ds.to_netcdf(filename,format='NETCDF4')
        
        print("Wrote out: ", filename)

    #-----------------------------------------------------------------------------
        
    hrrr_file = str(os.path.join(in_dir, "%s_%s.nc" % (day, suffix_name[0])))
    rrfs_file = str(os.path.join(in_dir, "%s_%s.nc" % (day, suffix_name[1])))
    
    filenames = (hrrr_file, rrfs_file)
    
    klevels = np.arange(11)
    
    # Open data sets

    hrrr = xr.open_dataset(hrrr_file) 
    rrfs = xr.open_dataset(rrfs_file)
    
    ds_objs = (hrrr, rrfs)
    
    for ds, file in zip(ds_objs, filenames):
        
        tic = time.perf_counter()
        
        print(file)
    
        # create NHHD
        
        for t in np.arange(2):

            u = np.nan_to_num(ds.u_interp.isel(fhour=t,nz=klevels).values).astype('float64')
            v = np.nan_to_num(ds.v_interp.isel(fhour=t,nz=klevels).values).astype('float64')
            w = np.nan_to_num(ds.w_interp.isel(fhour=t,nz=klevels).values).astype('float64')

            nz, ny, nx = u.shape[0:3]
            
            nhours = ds.dims['fhour']
            nhours = 2

            dims = (nz, ny, nx)  # Z Y, X
            dx   = (0.25, 3, 3)  # dz, dy, dx

            vfield = np.stack((u, v, w), axis=3)

            nhhd = nHHD(grid=dims, spacings=dx)

            nhhd.decompose(vfield)
            
            if t == 0:
                
                ur = np.zeros((nhours, nz, ny, nx))
                vr = np.zeros((nhours, nz, ny, nx))
                wr = np.zeros((nhours, nz, ny, nx))
                ud = np.zeros((nhours, nz, ny, nx))
                vd = np.zeros((nhours, nz, ny, nx))
                wd = np.zeros((nhours, nz, ny, nx))
                uh = np.zeros((nhours, nz, ny, nx))
                vh = np.zeros((nhours, nz, ny, nx))
                wh = np.zeros((nhours, nz, ny, nx))

            ur[t], vr[t], wr[t] = np.squeeze(np.split(nhhd.r, 3, axis=3))

            ud[t], vd[t], wd[t] = np.squeeze(np.split(nhhd.d, 3, axis=3))

            uh[t], vh[t], wh[t] = np.squeeze(np.split(nhhd.h, 3, axis=3))

        write_xr(file, ur,vr,wr, ud,vd,wd, uh,vh,wh, np.arange(nhours), hrrr.z[0:11].values, hrrr.lats.values, hrrr.lons.values)  
        
        toc = time.perf_counter()
        
        print(f"NHHD took {toc - tic:0.4f} seconds")

# %%
in_dir  = "/work/wicker/ECONUS"
out_dir = "/work/wicker/CAM_analysis_tools/2022_spectra"
case_days = ["2022050400", 
             "2022051200",
             "2022051400",
             "2022051500",
             "2022051900",
             "2022052300",
             "2022052400",
             "2022052700",
             "2022053000",
             "2022060700"]

#case_days = ["2022060700"]

for d in case_days:
    print("Running day:  %s\n" % d)
    ret = compute_nhhd(in_dir, out_dir, d)
# Out:
# Running day:  2022050400
#
# /work/wicker/ECONUS/2022050400_HRRR_ECONUS.nc
# Wrote out:  /work/wicker/ECONUS/2022050400_HRRR_ECONUS_nhhd3D.nc
# NHHD took 103.8818 seconds
# /work/wicker/ECONUS/2022050400_RRFS_ECONUS.nc

# %%
ds = xr.open_dataset("/work/wicker/ECONUS/2022051200_HRRR_ECONUS_nhhd_nhhd.nc")


ur = ds.ur.values
vr = ds.vr.values
wr = ds.wr.values
ds.sizes

# %%
divx = (ur[:,:,2:] - ur[:,:,:-2]) / 6.0
divy = (vr[:,2:,:] - vr[:,:-2,:]) / 6.0
divz = (wr[2:,:,:] - wr[:-2,:,:]) / 0.5

print(divx.shape, divy.shape, divz.shape)

dtotal = divx[1:-1,1:-1,:] + divy[1:-1,:,1:-1] + divz[:,1:-1,1:-1]

print(dtotal.shape)

print(dtotal.max(), dtotal.min())
# Out:
# (33, 959, 1153) (33, 957, 1155) (31, 959, 1155)
# (31, 957, 1153)
# 1.9539925233402755e-14 -1.9539925233402755e-14

# %%
ud = ds.ud.values
vd = ds.vd.values
wd = ds.wd.values

rotx = (ud[:,2:,2:] - ud[:,:-2,:-2]) / 6.0
roty = (vd[:,2:,2:] - vd[:,:-2,:-2]) / 6.0
#divz = (wr[2:,:,:] - wr[:-2,:,:]) / 0.5

rot = roty - rotx
print(rot.max(), rot.min())
# Out:
# 3.1539937143618317 -3.943957202400308

# %%
#-----------------------------------------------------------------
#
# This code can run and plot power spectra from a single day
#

def run_spectral_analysis(in_dir, out_dir, day, suffix_name = ["HRRR_ECONUS", "RRFS_ECONUS"], analysis_levels = [4, 34]):
    

    hrrr_file = str(os.path.join(in_dir, "%s_%s.nc" % (day, suffix_name[0])))
    rrfs_file = str(os.path.join(in_dir, "%s_%s.nc" % (day, suffix_name[1])))
    
    print(hrrr_file)
    print(rrfs_file)
    
    # Open data sets

    hrrr = xr.open_dataset(hrrr_file) 
    rrfs = xr.open_dataset(rrfs_file)
    
    zlevels = hrrr.z
    
    # create NHHD
    
    klevels = np.arange(11)
    
    hrrr_u = np.nan_to_num(hrrr.u_interp.isel(fhour=3,nz=klevels).values).astype('float64')
    hrrr_v = np.nan_to_num(hrrr.v_interp.isel(fhour=3,nz=klevels).values).astype('float64')
    hrrr_w = np.nan_to_num(hrrr.w_interp.isel(fhour=3,nz=klevels).values).astype('float64')
    
    print(hrrr_u.shape)

    nz, ny, nx = hrrr_u.shape[0:3]

    dims = (nz, ny, nx)  # Z Y, X
    dx   = (0.25, 3, 3)  # dz, dy, dx
        
    vfield = np.stack((hrrr_u, hrrr_v, hrrr_w), axis=3)

    nhhd = nHHD(grid=dims, spacings=dx)
    nhhd.decompose(vfield)
    print(nhhd.r.shape)

    hrrr_ur, hhhr_vr, hhhr_wr = np.squeeze(np.split(nhhd.r, 3, axis=3))

    hrrr_ud, hrrr_vd, hrrr_wd = np.squeeze(np.split(nhhd.d, 3, axis=3))

    hrrr_uh, hrrr_vh, hrrr_wh = np.squeeze(np.split(nhhd.h, 3, axis=3))

    print("Created HRRR NHHD")
    
    rrfs_u = np.nan_to_num(rrfs.u_interp.isel(fhour=3,nz=klevels).values).astype('float64')
    rrfs_v = np.nan_to_num(rrfs.v_interp.isel(fhour=3,nz=klevels).values).astype('float64')
    rrfs_w = np.nan_to_num(rrfs.w_interp.isel(fhour=3,nz=klevels).values).astype('float64')
    
    print(rrfs_u.shape)

    nz, ny, nx = rrfs_u.shape[0:3]

    dims = (nz, ny, nx)  # Y, X
    dx = (0.25, 3, 3)             # dy, dx

    vfield = np.stack((rrfs_u, rrfs_v, rrfs_w), axis=3)
    
    nhhd = nHHD(grid=dims, spacings=dx)
    nhhd.decompose(vfield)
    
    print(nhhd.r.shape)

    rrfs_ur, rrfs_vr, rrfs_wr = np.squeeze(np.split(nhhd.r, 3, axis=3))

    rrfs_ud, rrfs_vd, rrfs_wd = np.squeeze(np.split(nhhd.d, 3, axis=3))
    
    rrfs_uh, rrfs_vh, rrfs_wh = np.squeeze(np.split(nhhd.h, 3, axis=3))
    
    print(rrfs_ur.shape)

    print("Created RRFS NHHD")
    
    # Loop over the analy_klevels to create multiple plots

    for k in analysis_levels:

        # these three levels are averaged together

        klevels = [k]
        
        # Compute spectra...

        fig = plt.figure(constrained_layout=True,figsize=(20,10))

        ylim = [1.0e4,1.0e15]
        axis    = 0
        func    = get_spectra2D_RAD
        detrend = True

        gs = gridspec.GridSpec(1, 2, figure=fig)

        ax1 = fig.add_subplot(gs[0, 0])

        # plot_spectra(rrfs_w, func=get_spectra2D_DCT, axis=axis, ax=[ax1], detrend=detrend, legend='', PScolor='g', ylim=ylim)       
        # plot_spectra(hrrr_w, func=get_spectra2D_DCT, axis=axis, ax=[ax1], detrend=detrend, legend='', PScolor='b', ptitle = 'W', ylim=ylim)

        plot_spectra(rrfs_ur, varray=rrfs_vr, func=func, axis=axis, ax=[ax1], detrend=detrend, legend='', PScolor='r', ylim=ylim)      
        plot_spectra(rrfs_uh, varray=rrfs_vh, func=func, axis=axis, ax=[ax1], detrend=detrend, legend='', PScolor='g', ylim=ylim) 
        plot_spectra(hrrr_uh, varray=hrrr_vh, func=func, axis=axis, ax=[ax1], detrend=detrend, legend='', PScolor='g', ylim=ylim)  
        plot_spectra(hrrr_ur, varray=rrfs_vr, func=func, axis=axis, ax=[ax1], detrend=detrend, legend='HRRR:black\nRRFS:red',ptitle='VKE',PScolor='k',LinsborgSlope=True,ylim=ylim)
            
        ax1 = fig.add_subplot(gs[0, 1])
        
        # plot_spectra(rrfs_u, varray=rrfs_v, func=get_spectra2D_DCT, axis=axis, ax=[ax1], detrend=detrend, legend='', PScolor='g', ylim=ylim, PSline='-.')    
        # plot_spectra(hrrr_u, varray=hrrr_v, func=get_spectra2D_DCT, axis=axis, ax=[ax1], detrend=detrend, legend='', PScolor='b', ptitle = 'Hor. KE', ylim=ylim, PSline='-.')

        plot_spectra(rrfs_ud, varray=rrfs_vd, func=func, axis=axis, ax=[ax1], detrend=detrend, legend='', PScolor='r', ylim=ylim)
        plot_spectra(hrrr_ud, varray=hrrr_vd, func=func, axis=axis, ax=[ax1], detrend=detrend, legend='HRRR:black\nRRFS:red', ptitle = 'DKE', PScolor='k', LinsborgSlope=True, ylim=ylim)

        plt.suptitle("W-Spectra Avg Case Day %s \n Height Level: %3.1f km" % (day, zlevels[k]/1000.), fontsize=20)

        plt.savefig("%s/%s_%s_%3.1fkm.png" % (out_dir, day, 'W_KE_Spectra', zlevels[k]/1000.),bbox_inches='tight', dpi=300)

# %%
in_dir  = "/work/wicker/ECONUS"
out_dir = "/work/wicker/CAM_analysis_tools/2022_spectra"
case_days = ["2022051400"]

            # ["2022050400"]
            # # ,"2022051200",
            # # "2022051400",
            # # "2022051500",
            # # "2022051900",
            # # "2022052300",
            # # "2022052400",
            # # "2022052700",
            # # "2022053000",
            # # "2022060700"]

#case_days = ["2022060700"]

for d in case_days:
    print("Running day:  %s\n" % d)
    ret = run_spectral_analysis(in_dir, out_dir, d, analysis_levels = [4])
# Out:
# Running day:  2022051400
#
# /work/wicker/ECONUS/2022051400_HRRR_ECONUS.nc
# /work/wicker/ECONUS/2022051400_RRFS_ECONUS.nc
# (11, 959, 1155)
# (11, 959, 1155, 3)
# Created HRRR NHHD
# (11, 959, 1155)
# (11, 959, 1155, 3)
# (11, 959, 1155)
# Created RRFS NHHD
# ----------------------------------------------------------------------------------------------------
# plot_spectra: Computing power spectrum using function: get_spectra2D_RAD
# plot_spectra: Spectrum computed for KE
# plot_spectra: DETREND = True
#
#                     ----------------------------------------------------------------------------------------------------
#                     get_spectra2D_RAD is now being called
#
#
# ----------------------------------------------------------------------------------------------------
# plot_spectra: Computing power spectrum using function: get_spectra2D_RAD
# plot_spectra: Spectrum computed for KE
# plot_spectra: DETREND = True
#
#                     ----------------------------------------------------------------------------------------------------
#                     get_spectra2D_RAD is now being called
#
#
# ----------------------------------------------------------------------------------------------------
# plot_spectra: Computing power spectrum using function: get_spectra2D_RAD
# plot_spectra: Spectrum computed for KE
# plot_spectra: DETREND = True
#
#                     ----------------------------------------------------------------------------------------------------
#                     get_spectra2D_RAD is now being called
#
#
# ----------------------------------------------------------------------------------------------------
# plot_spectra: Computing power spectrum using function: get_spectra2D_RAD
# plot_spectra: Spectrum computed for KE
# plot_spectra: DETREND = True
#
#                     ----------------------------------------------------------------------------------------------------
#                     get_spectra2D_RAD is now being called
#
#
# ----------------------------------------------------------------------------------------------------
# plot_spectra: Computing power spectrum using function: get_spectra2D_RAD
# plot_spectra: Spectrum computed for KE
# plot_spectra: DETREND = True
#
#                     ----------------------------------------------------------------------------------------------------
#                     get_spectra2D_RAD is now being called
#
#
# ----------------------------------------------------------------------------------------------------
# plot_spectra: Computing power spectrum using function: get_spectra2D_RAD
# plot_spectra: Spectrum computed for KE
# plot_spectra: DETREND = True
#
#                     ----------------------------------------------------------------------------------------------------
#                     get_spectra2D_RAD is now being called

# %%
import matplotlib.ticker as mticker

analysis_levels  = [4, 34]

def update_ticks(x, pos):
    if x != 0.0:
        return "%2.1f" % (2.0/x)
    else:
        return r'$\infty$'

in_dir  = "/work/wicker/ECONUS"
out_dir = "/work/wicker/CAM_analysis_tools/2022_spectra"
case_days = ["2022050400",
            "2022051200",
            "2022051400",
            "2022051500",
            "2022051900",
            "2022052300",
            "2022052400",
            "2022052700",
            "2022053000",
            "2022060700"]

ncases = len(case_days)

avg_grid = 0.005 + 0.985* np.linspace(0.0, 1.0, num=100, endpoint=True)

ret_data =  {"HRRR":[], 
             "RRFS":[]}

avg_data = {"HRRR":np.zeros((ncases,avg_grid.shape[0],)), 
            "RRFS":np.zeros((ncases,avg_grid.shape[0],))}

func   = get_spectra2D_RAD
dtrend = True
axis   = None

delta  = False

suffix_names = ["HRRR","RRFS"]
region = "ECONUS"
#------------------------------------------------------------------------------------
#

print("\n====> Begin processing runs\n")

for k in analysis_levels:
    for n, day in enumerate(case_days):
        for run in suffix_names:

            print("\n----> Processing run: %s for day:  %s \n" % (run, day))
            
            myfile  = str(os.path.join(in_dir, "%s_%s_%s.nc" % (day, run, region)))
            print("          %s\n" % myfile)

            # Open data set

            data = xr.open_dataset(myfile)
            
            zlevels = data.z
            
            # Loop over the analy_klevels to create multiple plots

            # these five levels are averaged together

            klevels = [k-1, k, k+1]

            # Convert to numpy arrays, fill in zeros, compute horizontal TKE.

            data_w = np.nan_to_num(data.w_interp.isel(nz=klevels).values).astype('float64')

            # Compute spectra...

            ret = get_spectraND(data_w, func = func, dtrend = dtrend)

            ret_data[run].append(ret)

            avg_data[run][n][:] = np.interp(avg_grid, ret[2], ret[1])
            
            data.close()


# Now post the runs....

    legend='HRRR:black\nRRFS:red'

    avg_hrrr = avg_data['HRRR'].mean(axis=0)
    avg_rrfs = avg_data['RRFS'].mean(axis=0)

    fig, axes = plt.subplots(1, 1, constrained_layout=True,figsize=(10,10))

    if delta:
        delta_rrfs = avg_rrfs[12]-avg_hrrr[12]
        axes.loglog(avg_grid, avg_hrrr+delta_rrfs,  color='black')
    else:
        axes.loglog(avg_grid, avg_hrrr,  color='black')
        
    axes.loglog(avg_grid, avg_rrfs, color='red')
    
    axes.set_xlim(2.0/avg_grid.shape[0], 1.0)

    axes.annotate("%s" % legend, xy=(0.10, 0.25), xycoords='axes fraction', color='k',fontsize=18)
    axes.xaxis.set_major_formatter(mticker.FuncFormatter(update_ticks))

    ylim    = [0.1,1.0e4]
        
    axes.set_ylim(ylim[0], ylim[1])

    ylabel = 5. * ylim[0]

    xoffset = [0.01, 0.005, 0.0035, 0.001]

    for n, w in enumerate([4.0, 8.0, 12.0, 16.0]):
        axes.axvline(x = (2.0/w), color = 'grey', label = 'axvline - full height')  
        axes.annotate(r"%d$\Delta$x" % w, xy=(2.0/w + xoffset[n], ylabel), xycoords='data', color='k',fontsize=12)

    axes.set_xlabel(r"Wavelength in ($\Delta$x)", fontsize=16)
    axes.set_ylabel(r"W Spectral Density (m$^3$ s$^{-2}$)", fontsize=18)

    # plt.title(ptitle, fontsize=18)

    plt.suptitle("W_SPECTRA_ALL_DAYS: Height Level: %3.1f km" % (zlevels[k]/1000.), fontsize=16)

    plt.savefig("%s/%s_%3.1fkm.png" % (out_dir, 'W_SPECTRA_ALL', zlevels[k]/1000.),bbox_inches='tight',dpi=300)
# Out:
# ====> Begin processing runs
#
#
# ----> Processing run: HRRR for day:  2022050400
#
#           /work/wicker/ECONUS/2022050400_HRRR_ECONUS.nc
#
#           ----------------------------------------------------------------------------------------------------
#           get_spectraND: Reshaped array so that spectra averaged over outer dimension: 18
#
#                     ----------------------------------------------------------------------------------------------------
#                     get_spectra2D_RAD is now being called
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.07250541422              0.07247282481
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1107912447               0.1107437826
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1652174086               0.1651505941
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.08347836833              0.08345506194
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             0.147783082               0.1477440529
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.2450364487               0.2449748496
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             0.118959817               0.1189309421
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1904276925               0.1903828809
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.2840914379               0.2840264413
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1149367363               0.1148956926
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1852906281               0.1852305933
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.2766911453               0.2766122166
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1374286579                0.137395241
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.2107933691               0.2107438116
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.3007080334               0.3006388797
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1399764332               0.1399342932
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.2169727469               0.2169115623
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.3099248877               0.3098433146
#
#
#
#
# ----> Processing run: RRFS for day:  2022050400
#
#           /work/wicker/ECONUS/2022050400_RRFS_ECONUS.nc
#
#           ----------------------------------------------------------------------------------------------------
#           get_spectraND: Reshaped array so that spectra averaged over outer dimension: 18
#
#                     ----------------------------------------------------------------------------------------------------
#                     get_spectra2D_RAD is now being called
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.03135159365              0.03134838681
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.05304848707               0.0530429313
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.08569264499              0.08568381631
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.04807116382              0.04806852798
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.08179055874              0.08178611948
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1316583314               0.1316512419
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.07982198381              0.07981903763
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1286954088               0.1286908979
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1930188792               0.1930122781
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.09026202335              0.09025818581
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1355496406               0.1355439982
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1916129781               0.1916048558
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.04442734503              0.04442509398
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.06600729862              0.06600383178
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.09293196414              0.09292696666
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.07013190405              0.07012889029
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1052620976               0.1052574303
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1482649196               0.1482582335
#
#
#
#
# ----> Processing run: HRRR for day:  2022051200
#
#           /work/wicker/ECONUS/2022051200_HRRR_ECONUS.nc
#
#           ----------------------------------------------------------------------------------------------------
#           get_spectraND: Reshaped array so that spectra averaged over outer dimension: 21
#
#                     ----------------------------------------------------------------------------------------------------
#                     get_spectra2D_RAD is now being called
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.03494164717              0.03493334871
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.05938263233              0.05936826974
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.09054514522              0.09052274193
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.06406477901              0.06404935986
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1020122324               0.1019876725
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1474374946               0.1474015177
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.09551415436              0.09549313158
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1474012024                0.147368373
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.2057049337               0.2056573413
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1208734877               0.1208442528
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             0.178607273               0.1785648634
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.2400354839               0.2399778444
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.09898912108              0.09896912183
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             0.142194154               0.1421660328
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1873953932               0.1873577314
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.0681368275              0.06811712611
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.09738529581              0.09735734373
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1305088426               0.1304711746
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.04965399898              0.04964191643
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.07002884027              0.07001272099
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.08681910979              0.08679886485
#
#
#
#
# ----> Processing run: RRFS for day:  2022051200
#
#           /work/wicker/ECONUS/2022051200_RRFS_ECONUS.nc
#
#           ----------------------------------------------------------------------------------------------------
#           get_spectraND: Reshaped array so that spectra averaged over outer dimension: 21
#
#                     ----------------------------------------------------------------------------------------------------
#                     get_spectra2D_RAD is now being called
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.02966542082              0.02966230627
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.04661970199              0.04661485421
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.06854183992              0.06853495138
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.04335748632              0.04335531861
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.06464622959              0.06464296871
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.09066130026              0.09065652278
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.05534432747              0.05534138643
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.08235515796              0.08235091316
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1121227217               0.1121171541
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.05664264365              0.05664062064
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.08624149661               0.0862382848
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1194155345               0.1194108476
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.06159066516              0.06158778203
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.08452740818              0.08452332037
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             0.107393381                0.107388185
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.04363591261              0.04363413467
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.06291488042              0.06291230617
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.08243532295              0.08243193105
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.03575401783              0.03575268954
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.04869068188              0.04868890614
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.05893008405              0.05892781823
#
#
#
#
# ----> Processing run: HRRR for day:  2022051400
#
#           /work/wicker/ECONUS/2022051400_HRRR_ECONUS.nc
#
#           ----------------------------------------------------------------------------------------------------
#           get_spectraND: Reshaped array so that spectra averaged over outer dimension: 21
#
#                     ----------------------------------------------------------------------------------------------------
#                     get_spectra2D_RAD is now being called
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.04963259359               0.0496096928
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.07538065219               0.0753438732
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1115476345                0.111491359
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.07047098068              0.07044278532
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1000152224              0.09997328295
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1385199156               0.1384591247
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.0799436323              0.07991716504
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1124601454               0.1124226417
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1519376681                0.151885895
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.07790028727              0.07787599098
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1065624763               0.1065301983
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1408347677               0.1407924711
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.06645827027              0.06643263384
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.0904919131               0.0904575206
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1189076148                0.118862319
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.04839299479              0.04837910203
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.06529030002              0.06527105609
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.08394170105               0.0839158502
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.03564740941              0.03563774394
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.04494196487               0.0449297855
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.05471027041              0.05469456046
#
#
#
#
# ----> Processing run: RRFS for day:  2022051400
#
#           /work/wicker/ECONUS/2022051400_RRFS_ECONUS.nc
#
#           ----------------------------------------------------------------------------------------------------
#           get_spectraND: Reshaped array so that spectra averaged over outer dimension: 21
#
#                     ----------------------------------------------------------------------------------------------------
#                     get_spectra2D_RAD is now being called
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.06968698822              0.06968336948
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1096734157                0.109667855
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1627001586               0.1626918314
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.06029743595              0.06029410094
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.09467629486              0.09467120335
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1407896561               0.1407822657
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.08013210246              0.08012758882
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1251095379               0.1251023865
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1824628699               0.1824522754
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.07419925867              0.07419588294
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1148856213                0.114880463
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1649920563               0.1649847325
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.07429438486               0.0742916425
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1150427961               0.1150386094
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1658083853               0.1658024309
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.04329130944              0.04328901639
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.06360364812              0.06360026644
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.08835102348              0.08834613207
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.0345423211              0.03453980035
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.05373096243              0.05372696755
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.07790317903              0.07789737081
#
#
#
#
# ----> Processing run: HRRR for day:  2022051500
#
#           /work/wicker/ECONUS/2022051500_HRRR_ECONUS.nc
#
#           ----------------------------------------------------------------------------------------------------
#           get_spectraND: Reshaped array so that spectra averaged over outer dimension: 27
#
#                     ----------------------------------------------------------------------------------------------------
#                     get_spectra2D_RAD is now being called
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.06292933366              0.06290505891
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.09303543383              0.09299734764
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1359293479               0.1358694815
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.09906117259              0.09902178324
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1356015915               0.1355458795
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1852219325               0.1851443347
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1215423756               0.1215010205
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1565975883               0.1565425879
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.2030237645               0.2029487664
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1212702368               0.1212293378
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1512679325               0.1512141768
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1871442202               0.1870751157
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.07123960515               0.0712193415
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.08811857065              0.08809323913
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1066952611                 0.10666324
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.07399493888              0.07397632054
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.09074487554              0.09072226937
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             0.106601859               0.1065747796
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.05709947782              0.05708719324
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.07408990558              0.07407422773
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.09131446568              0.09129484066
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.03435326219              0.03434430445
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.04000852398              0.03999783099
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.04459168658               0.0445788232
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.02533011061              0.02532450978
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.03013403145              0.03012701112
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.03491847802              0.03490943014
#
#
#
#
# ----> Processing run: RRFS for day:  2022051500
#
#           /work/wicker/ECONUS/2022051500_RRFS_ECONUS.nc
#
#           ----------------------------------------------------------------------------------------------------
#           get_spectraND: Reshaped array so that spectra averaged over outer dimension: 21
#
#                     ----------------------------------------------------------------------------------------------------
#                     get_spectra2D_RAD is now being called
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.0384859053              0.03848133479
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.05996241689              0.05995508127
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.09053610741              0.09052526581
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.05394797374              0.05394464005
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.08461360059               0.0846084008
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1270198862               0.1270121503
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.03150010149              0.03149844519
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.04426264691               0.0442601764
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.06127519012              0.06127147154
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.02681779241              0.02681517541
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.03916817489              0.03916434786
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.05680092963              0.05679566533
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.0148394106              0.01483776784
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.02407033867               0.0240679864
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.03796230695              0.03795910831
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.02738922145              0.02738575166
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.04652075398              0.04651526661
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.07332959784              0.07332144946
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.01039924451              0.01039854486
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.01589689687              0.01589593941
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.02347518112              0.02347379494
#
#
#
#
# ----> Processing run: HRRR for day:  2022051900
#
#           /work/wicker/ECONUS/2022051900_HRRR_ECONUS.nc
#
#           ----------------------------------------------------------------------------------------------------
#           get_spectraND: Reshaped array so that spectra averaged over outer dimension: 30
#
#                     ----------------------------------------------------------------------------------------------------
#                     get_spectra2D_RAD is now being called
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.01251023997              0.01250546186
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.01838342828              0.01837589974
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.0260167879              0.02600569489
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.04876851885              0.04875442687
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.07637174228               0.0763509058
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                            0.1151474388               0.1151177131
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                           0.07227509839              0.07224913674
#
#                                         Input array variance         DFT Variance
# ...
#                                             3.410885819                3.410137201
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             3.624083011                3.623189666
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             3.533645986                 3.53266816
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             2.617785262                2.617276274
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             2.579354588                2.578844992
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             2.382120237                2.381669237
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             3.818425635                 3.81793932
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                              3.74236656                3.741915644
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             3.380761747                3.380411026
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             5.743140691                5.742482643
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             5.709442605                5.708879113
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             5.335866585                5.335378506
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             3.962607411                3.962144033
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             3.700791939                3.700372637
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             3.215751436                3.215393187
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             9.102005246                9.101399407
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             8.454457009                8.453860764
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             7.208783293                7.208287531
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             9.711687315                9.711081127
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             9.510112001                9.509539705
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             8.693456034                8.692968098
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             6.817690974                6.817012911
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             6.781975879                6.781398961
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             6.250069354                6.249614456
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             4.117530036                4.117011548
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             3.648170992                  3.6477453
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             2.992033704                2.991695291
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             5.582353441                5.581366599
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             5.545290227                5.544267783
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             5.143222602                5.142215464
#
#
#
#
# ----> Processing run: RRFS for day:  2022060700
#
#           /work/wicker/ECONUS/2022060700_RRFS_ECONUS.nc
#
#           ----------------------------------------------------------------------------------------------------
#           get_spectraND: Reshaped array so that spectra averaged over outer dimension: 33
#
#                     ----------------------------------------------------------------------------------------------------
#                     get_spectra2D_RAD is now being called
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             3.336789908                3.336523852
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             3.518963246                3.518677163
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             3.621714402                3.621405958
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             4.559508785                4.559358938
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             4.535274992                 4.53513024
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             4.296952495                4.296820977
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             10.55031252                10.54989586
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             11.09170056                11.09125769
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             11.32556112                 11.3250918
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             6.883743626                6.883507202
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             7.030578523                7.030313195
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             6.903322964                6.903027508
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             7.145432989                7.145297997
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             7.363193089                7.363058971
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             7.320633501                7.320495837
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             5.122912558                5.122670243
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             5.044533956                 5.04427605
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             4.800289087                4.800023038
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             5.959951685                5.959767118
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             5.981214857                5.981014494
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             5.815607306                5.815395148
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                              5.47531161                5.475121758
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             5.740831511                5.740648046
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                              5.87744335                5.877270197
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             10.49156958                10.49117625
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             11.59437892                11.59395797
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             12.51929733                12.51884868
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             12.28561818                12.28530669
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             13.63483234                13.63452492
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                               14.898402                 14.8981006
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             10.33165987                  10.331066
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             11.53063983                11.52999765
#
#                                         Input array variance         DFT Variance
#                                         -----------------------------------------
#                                             12.55869993                12.55804358

# %%
import matplotlib.ticker as mticker

analysis_levels  = [4, 34]

def update_ticks(x, pos):
    if x != 0.0:
        return "%2.1f" % (2.0/x)
    else:
        return r'$\infty$'

in_dir  = "/work/wicker/ECONUS"
out_dir = "/work/wicker/CAM_analysis_tools/2022_spectra"
case_days = ["2022050400",
            "2022051200",
            "2022051400",
            "2022051500",
            "2022051900",
            "2022052300",
            "2022052400",
            "2022052700",
            "2022053000",
            "2022060700"]

ncases = len(case_days)

avg_grid = 0.005 + 0.985* np.linspace(0.0, 1.0, num=100, endpoint=True)

ret_data =  {"HRRR":[], 
             "RRFS":[]}

avg_data = {"HRRR":np.zeros((ncases,avg_grid.shape[0],)), 
            "RRFS":np.zeros((ncases,avg_grid.shape[0],))}

func = get_spectra2D_RAD
dtrend = False
axis = None

delta = False

suffix_names = ["HRRR","RRFS"]
region = "ECONUS"
#------------------------------------------------------------------------------------
#

print("\n====> Begin processing runs\n")

for k in analysis_levels:
    for n, day in enumerate(case_days):
        for run in suffix_names:

            print("\n----> Processing run: %s for day:  %s \n" % (run, day))
            
            myfile  = str(os.path.join(in_dir, "%s_%s_%s.nc" % (day, run, region)))
            print("          %s\n" % myfile)

            # Open data set

            data = xr.open_dataset(myfile)
            
            zlevels = data.z
            
            # Loop over the analy_klevels to create multiple plots

            # these five levels are averaged together

            klevels = [k-1, k, k+1]

            # Convert to numpy arrays, fill in zeros, compute horizontal TKE.

            data_u = np.nan_to_num(data.u_interp.isel(nz=klevels).values).astype('float64')
            data_v = np.nan_to_num(data.v_interp.isel(nz=klevels).values).astype('float64')

            # Compute spectra...

            ret = get_spectraND(data_u, varray=data_v, func = func, detrend=dtrend)

            ret_data[run].append(ret)

            avg_data[run][n][:] = np.interp(avg_grid, ret[2], ret[1])
            
            data.close()

# Now post the runs....

    legend='HRRR:black\nRRFS:red'

    avg_hrrr = avg_data['HRRR'].mean(axis=0)
    avg_rrfs = avg_data['RRFS'].mean(axis=0)

    fig, axes = plt.subplots(1, 1, constrained_layout=True,figsize=(10,10))

    if delta:
        delta_rrfs = avg_rrfs[12]-avg_hrrr[12]
        axes.loglog(avg_grid, avg_hrrr+delta_rrfs,  color='black')
    else:
        axes.loglog(avg_grid, avg_hrrr,  color='black')
        
    axes.loglog(avg_grid, avg_rrfs, color='red')
    
    axes.set_xlim(2.0/avg_grid.shape[0], 1.0)

    axes.annotate("%s" % legend, xy=(0.10, 0.25), xycoords='axes fraction', color='k',fontsize=18)
    axes.xaxis.set_major_formatter(mticker.FuncFormatter(update_ticks))

    ylim = [1.0e1,1.0e6]

    axes.set_ylim(ylim[0], ylim[1])

    ylabel = 5. * ylim[0]

    xoffset = [0.0075, 0.0035, 0.0025, 0.001]

    for n, w in enumerate([4.0, 8.0, 12.0, 16.0]):
        axes.axvline(x = (2.0/w), color = 'grey', label = 'axvline - full height')  
        axes.annotate(r"%d$\Delta$x" % w, xy=(2.0/w + xoffset[n], ylabel), xycoords='data', color='k',fontsize=12)
        
    xpt = [2.0/16.,2.0/2.0]
    dlnx = np.log(xpt[1]) - np.log(xpt[0])
    y1   = ylim[1]/(100.)
    y0   = np.exp(np.log(y1) + 5./3. * dlnx)
    ypt  = [y0,y1]
    axes.loglog(xpt, ypt, color='red',linestyle='-.',label='k$^{-5/3}$')

    axes.set_xlabel(r"Wavelength in ($\Delta$x)", fontsize=16)
    axes.set_ylabel(r"KE Spectral Density (m$^3$ s$^{-2}$)", fontsize=18)

    plt.suptitle("KE_SPECTRA_ALL_DAYS: Height Level: %3.1f km" % (zlevels[k]/1000.), fontsize=16)

    plt.savefig("%s/%s_%3.1fkm.png" % (out_dir, 'KE_SPECTRA_ALL', zlevels[k]/1000.),bbox_inches='tight',dpi=300)
